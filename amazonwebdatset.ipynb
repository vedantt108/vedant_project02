# %%
# import libraries
from bs4 import BeautifulSoup
import requests
import time
import datetime

import smtplib

# %%
# connect to website
URL = 'https://www.amazon.in/gp/aw/d/B0CX5KRJWS'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
    "Accept-Language": "en-IN,en;q=0.9"
}

page = requests.get(URL, headers=headers)

soup = BeautifulSoup(page.content, "html.parser")

# Product title
title_element = soup.find(id='productTitle')

if title_element:
    title = title_element.get_text(strip=True)
else:
    title = "Title not found"

# Product price
price_element = soup.select_one("span.a-price-whole")

if price_element:
    price = price_element.get_text(strip=True)
else:
    price = "Price not found"

print("Title:", title)
print("Price:", price)
# Out:
# Title: T-Shirt for Men – 100% Cotton Mountain T-Shirt Half Sleeve Round Neck Graphic Print | Unisex Regular & Oversized Fit | 180/220 GSM | S–5XL | Black, Blue, Maroon, White, Yellow, Grey
# Price: 499

# %%
import datetime
today = datetime.date.today()

print(today)
# Out:
# 2026-09-11

# %%
import csv

header = ['Title', 'Price', 'Date']
data = [title, price]

#with open('AmazonWebScraperDataset.csv', 'w', newline='', encoding='UTF8') as f:
 #   writer = csv.writer(f)
  #  writer.writerow(header)
   # writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\DELL\Downloads\AmazonWebScraperDataset.csv')

print(df)
# Out:
#                                                Title  Price  Date
# 0  T-Shirt for Men – 100% Cotton Mountain T-Shirt...    499   NaN
# 1  T-Shirt for Men – 100% Cotton Mountain T-Shirt...    499   NaN

# %%
# Now we are appending data to csv
with open('AmazonWebScraperDataset.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():
    URL = 'https://www.amazon.in/gp/aw/d/B0CX5KRJWS'

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36",
        "Accept-Language": "en-IN,en;q=0.9"
    }

    page = requests.get(URL, headers=headers)

    soup = BeautifulSoup(page.content, "html.parser")

    title_element = soup.find(id='productTitle')

    if title_element:
        title = title_element.get_text(strip=True)
    else:
        title = "Title not found"

    price_element = soup.select_one("span.a-price-whole")

    if price_element:
        price = price_element.get_text(strip=True)
        price = price.replace(",", "")
        price = int(price)
    else:
        price = None

    print(title)
    print(price)

    # Send email only when price is below ₹299
    if price is not None and price < 299:
        send_mail()
    else:
        print("Price is not below ₹299")

# %%
import requests
from bs4 import BeautifulSoup

# %%
check_price()
# Out:
# T-Shirt for Men – 100% Cotton Mountain T-Shirt Half Sleeve Round Neck Graphic Print | Unisex Regular & Oversized Fit | 180/220 GSM | S–5XL | Black, Blue, Maroon, White, Yellow, Grey
# 499
# Price is not below ₹299

# %%
while(True):
    check_price()
    time.sleep(5)
# Out:
# T-Shirt for Men – 100% Cotton Mountain T-Shirt Half Sleeve Round Neck Graphic Print | Unisex Regular & Oversized Fit | 180/220 GSM | S–5XL | Black, Blue, Maroon, White, Yellow, Grey
# 499
# Price is not below ₹299
# T-Shirt for Men – 100% Cotton Mountain T-Shirt Half Sleeve Round Neck Graphic Print | Unisex Regular & Oversized Fit | 180/220 GSM | S–5XL | Black, Blue, Maroon, White, Yellow, Grey
# 499
# Price is not below ₹299
# T-Shirt for Men – 100% Cotton Mountain T-Shirt Half Sleeve Round Neck Graphic Print | Unisex Regular & Oversized Fit | 180/220 GSM | S–5XL | Black, Blue, Maroon, White, Yellow, Grey
# 499
# Price is not below ₹299
# T-Shirt for Men – 100% Cotton Mountain T-Shirt Half Sleeve Round Neck Graphic Print | Unisex Regular & Oversized Fit | 180/220 GSM | S–5XL | Black, Blue, Maroon, White, Yellow, Grey
# 499
# Price is not below ₹299
# ...

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\DELL\Downloads\AmazonWebScraperDataset.csv')

print(df)

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
    server.ehlo()

    server.login('vedantb8844@gmail.com', 'YOUR_APP_PASSWORD')

    subject = "The shirt you want is below 299! Now is your chance to buy it"
    body = "Vedant, This is the moment we have been waiting for. Now is your chance to pick up the shirt of your dreams."

    msg = f"Subject: {subject}\n\n{body}"

    server.sendmail(
        'vedantb8844@gmail.com',
        'vedantb8844@gmail.com',
        msg
    )

    server.quit()

    print("Email sent successfully!")

# %%
check_price()
